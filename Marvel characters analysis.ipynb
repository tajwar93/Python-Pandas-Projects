# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

sns.set_style('whitegrid')
plt.rcParams['font.size']=12
plt.rcParams['figure.figsize']=(15,5)
plt.rcParams['figure.constrained_layout.use'] = True

df1=pd.read_csv(r'C:\Users\TajwarAbtahee\OneDrive - JCW Resourcing\Desktop\Python\practice\charcters_stats.csv')
df2=pd.read_csv(r'C:\Users\TajwarAbtahee\OneDrive - JCW Resourcing\Desktop\Python\practice\marvel_characters_info.csv')

df1
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
df2
# Out:
#       ID             Name Alignment  Gender EyeColor               Race  \
# 0      0           A-Bomb      good    Male   yellow              Human
# 1      1       Abe Sapien      good    Male     blue      Icthyo Sapien
# 2      2         Abin Sur      good    Male     blue            Ungaran
# 3      3      Abomination       bad    Male    green  Human / Radiation
# 4      4          Abraxas       bad    Male     blue      Cosmic Entity
# ..   ...              ...       ...     ...      ...                ...
# 729  729  Yellowjacket II      good  Female     blue              Human
# 730  730             Ymir      good    Male    white        Frost Giant
# 731  731             Yoda      good    Male    brown     Yoda's species
# 732  732          Zatanna      good  Female     blue              Human
# 733  733             Zoom       bad    Male      red                  -
#
#             HairColor          Publisher SkinColor  Height  Weight
# ...

# %%
df=df1.merge(df2,how='inner',on='Name')
df
# Out:
#                 Name Alignment_x  Intelligence  Strength  Speed  Durability  \
# 0             A-Bomb        good            38       100     17          80
# 1         Abe Sapien        good            88        14     35          42
# 2           Abin Sur        good            50        90     53          64
# 3        Abomination         bad            63        80     53          90
# 4            Abraxas         bad            88       100     83          99
# ..               ...         ...           ...       ...    ...         ...
# 595     Yellowjacket        good            88        10     12          28
# 596  Yellowjacket II        good            50        10     35          28
# 597             Ymir        good            50       100     27         100
# 598          Zatanna        good            75        10     23          28
# 599             Zoom         bad            50        10    100          28
#
# ...

# %%
df=df[df.Publisher=='Marvel Comics']
df.drop(columns=['SkinColor','ID','Alignment_y'],inplace=True)
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.corr().style.background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
# #T_19e97_row0_col0,#T_19e97_row1_col1,#T_19e97_row2_col2,#T_19e97_row3_col3,#T_19e97_row4_col4,#T_19e97_row5_col5,#T_19e97_row6_col6,#T_19e97_row7_col7,#T_19e97_row8_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_19e97_row0_col1{
#             background-color:  #fece7c;
#             color:  #000000;
#         }#T_19e97_row0_col2,#T_19e97_row0_col3{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_19e97_row0_col4{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_19e97_row0_col5{
#             background-color:  #cfeb85;
#             color:  #000000;
#         }#T_19e97_row0_col6{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_19e97_row0_col7{
#             background-color:  #ea5739;
#             color:  #000000;
#         }#T_19e97_row0_col8{
#             background-color:  #db382b;
# ...

# %%
sns.pairplot(df,hue='Alignment_x')
plt.show()
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning:
#
# This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.

# %%
sns.pairplot(df,hue='Gender',kind='reg')
plt.show()
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning:
#
# This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.

# %%
px.scatter(df,x='Height',y='Weight',color='Gender',hover_name='Name')
# Out:
# <div>                            <div id="b3a7f529-0125-4481-bdca-4e46af22badb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3a7f529-0125-4481-bdca-4e46af22badb")) {                    Plotly.newPlot(                        "b3a7f529-0125-4481-bdca-4e46af22badb",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Gender=Male<br>Height=%{x}<br>Weight=%{y}<extra></extra>","hovertext":["A-Bomb","Abomination","Abraxas","Agent Bob","Agent Zero","Air-Walker","Ammo","Angel","Annihilus","Ant-Man","Ant-Man II","Anti-Venom","Apocalypse","Archangel","Ares","Atlas","Azazel","Banshee","Bantam","Battlestar","Beak","Beast","Beetle","Beta Ray Bill","Beyonder","Big Man","Bird-Man","Bird-Man II","Bishop","Black Abbott","Black Bolt","Black Goliat
# ...

# %%
df.head()
# Out:
#           Name Alignment_x  Intelligence  Strength  Speed  Durability  Power  \
# 0       A-Bomb        good            38       100     17          80     17
# 3  Abomination         bad            63        80     53          90     55
# 4      Abraxas         bad            88       100     83          99    100
# 7    Agent Bob        good            10         8     13           5      5
# 8   Agent Zero        good            75        28     38          80     72
#
#    Combat  Total Gender EyeColor               Race HairColor      Publisher  \
# 0      64    316   Male   yellow              Human   No Hair  Marvel Comics
# 3      95    436   Male    green  Human / Radiation   No Hair  Marvel Comics
# 4      56    526   Male     blue      Cosmic Entity     Black  Marvel Comics
# 7      20     61   Male    brown              Human     Brown  Marvel Comics
# 8      95    388   Male        -                  -         -  Marvel Comics
#
#    Height  Weight
# 0   203.0   441.0
# ...

# %%
px.scatter(df,x='Height',y='Weight',color='Total',hover_name='Name')
# Out:
# <div>                            <div id="f8899024-83bb-487a-8097-d0481bf1580b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8899024-83bb-487a-8097-d0481bf1580b")) {                    Plotly.newPlot(                        "f8899024-83bb-487a-8097-d0481bf1580b",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Height=%{x}<br>Weight=%{y}<br>Total=%{marker.color}<extra></extra>","hovertext":["A-Bomb","Abomination","Abraxas","Agent Bob","Agent Zero","Air-Walker","Ammo","Angel","Angel Salvadore","Annihilus","Ant-Man","Ant-Man II","Anti-Venom","Apocalypse","Arachne","Archangel","Arclight","Ares","Ariel","Armor","Atlas","Aurora","Azazel","Banshee","Bantam","Battlestar","Beak","Beast","Beetle","Beta Ray Bill","Beyonder","Big Man","
# ...

# %%
df.head()
# Out:
#           Name Alignment_x  Intelligence  Strength  Speed  Durability  Power  \
# 0       A-Bomb        good            38       100     17          80     17
# 3  Abomination         bad            63        80     53          90     55
# 4      Abraxas         bad            88       100     83          99    100
# 7    Agent Bob        good            10         8     13           5      5
# 8   Agent Zero        good            75        28     38          80     72
#
#    Combat  Total Gender EyeColor               Race HairColor      Publisher  \
# 0      64    316   Male   yellow              Human   No Hair  Marvel Comics
# 3      95    436   Male    green  Human / Radiation   No Hair  Marvel Comics
# 4      56    526   Male     blue      Cosmic Entity     Black  Marvel Comics
# 7      20     61   Male    brown              Human     Brown  Marvel Comics
# 8      95    388   Male        -                  -         -  Marvel Comics
#
#    Height  Weight
# 0   203.0   441.0
# ...

# %%
fig,axes=plt.subplots(nrows=5,figsize=(15,20))

sns.countplot(df.Alignment_x,ax=axes[0])
sns.countplot(df.Gender,ax=axes[1])
df.EyeColor.value_counts().plot(kind='bar',ax=axes[2],xlabel='Eye Color')
df.Race.value_counts().plot(kind='bar',ax=axes[3],xlabel='Race')
df.HairColor.value_counts().plot(kind='bar',ax=axes[4],xlabel='Hair Color')

plt.show()

#most popular counts in each category
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df
# Out:
#                 Name Alignment_x  Intelligence  Strength  Speed  Durability  \
# 0             A-Bomb        good            38       100     17          80
# 3        Abomination         bad            63        80     53          90
# 4            Abraxas         bad            88       100     83          99
# 7          Agent Bob        good            10         8     13           5
# 8         Agent Zero        good            75        28     38          80
# ..               ...         ...           ...       ...    ...         ...
# 593            X-Man        good            88        53     53          95
# 594      Yellow Claw         bad             1         1      1           1
# 595     Yellowjacket        good            88        10     12          28
# 596  Yellowjacket II        good            50        10     35          28
# 597             Ymir        good            50       100     27         100
#
# ...

# %%
sns.distplot(df.Intelligence,label='Intelligence')
sns.distplot(df.Strength,label='Strength')
sns.distplot(df.Speed,label='Speed')
sns.distplot(df.Durability,label='Durability')
sns.distplot(df.Power,label='Power')
sns.distplot(df.Combat,label='Combat')
plt.legend()

plt.show()

#strength and speed are closer together and also higher in each group
# intelligence and power are also close together and seenm to go hand in hand
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# ...

# %%
fig,axes=plt.subplots(nrows=5)

sns.boxplot(df.Intelligence,ax=axes[0])
sns.boxplot(df.Strength,ax=axes[1])
sns.boxplot(df.Speed,ax=axes[2])
sns.boxplot(df.Durability,ax=axes[3])
sns.boxplot(df.Power,ax=axes[4])
sns.boxplot(df.Combat,ax=axes[5])

plt.show()
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# ...

# %%
df.head()

# %%
good=df[df.Alignment_x=='good']
bad=df[df.Alignment_x=='bad']

fig,axes=plt.subplots(ncols=2,nrows=7,figsize=(15,20))

good.sort_values('Intelligence',ascending=False).head(20).plot(kind='bar',x='Name',y='Intelligence',ax=axes[0,0])
bad.sort_values('Intelligence',ascending=False).head(20).plot(kind='bar',x='Name',y='Intelligence',color='r',ax=axes[0,1])

good.sort_values('Strength',ascending=False).head(20).plot(kind='bar',x='Name',y='Strength',ax=axes[1,0])
bad.sort_values('Strength',ascending=False).head(20).plot(kind='bar',x='Name',y='Strength',color='r',ax=axes[1,1])

good.sort_values('Speed',ascending=False).head(20).plot(kind='bar',x='Name',y='Speed',ax=axes[2,0])
bad.sort_values('Speed',ascending=False).head(20).plot(kind='bar',x='Name',y='Speed',color='r',ax=axes[2,1])

good.sort_values('Power',ascending=False).head(20).plot(kind='bar',x='Name',y='Power',ax=axes[3,0])
bad.sort_values('Power',ascending=False).head(20).plot(kind='bar',x='Name',y='Power',color='r',ax=axes[3,1])

good.sort_values('Combat',ascending=False).head(20).plot(kind='bar',x='Name',y='Combat',ax=axes[4,0])
bad.sort_values('Combat',ascending=False).head(20).plot(kind='bar',x='Name',y='Combat',color='r',ax=axes[4,1])

good.sort_values('Durability',ascending=False).head(20).plot(kind='bar',x='Name',y='Durability',ax=axes[5,0])
bad.sort_values('Durability',ascending=False).head(20).plot(kind='bar',x='Name',y='Durability',color='r',ax=axes[5,1])

good.sort_values('Total',ascending=False).head(20).plot(kind='bar',x='Name',y='Total',ax=axes[6,0])
bad.sort_values('Total',ascending=False).head(20).plot(kind='bar',x='Name',y='Total',color='r',ax=axes[6,1])

plt.show()

#most powerful heroes and villains in each stat category

# %%
fig,axes=plt.subplots(ncols=2,nrows=7,figsize=(15,20))

good.sort_values('Intelligence').head(20).plot(kind='bar',x='Name',y='Intelligence',ax=axes[0,0])
bad.sort_values('Intelligence').head(20).plot(kind='bar',x='Name',y='Intelligence',color='r',ax=axes[0,1])

good.sort_values('Strength').head(20).plot(kind='bar',x='Name',y='Strength',ax=axes[1,0])
bad.sort_values('Strength').head(20).plot(kind='bar',x='Name',y='Strength',color='r',ax=axes[1,1])

good.sort_values('Speed').head(20).plot(kind='bar',x='Name',y='Speed',ax=axes[2,0])
bad.sort_values('Speed').head(20).plot(kind='bar',x='Name',y='Speed',color='r',ax=axes[2,1])

good.sort_values('Power').head(20).plot(kind='bar',x='Name',y='Power',ax=axes[3,0])
bad.sort_values('Power').head(20).plot(kind='bar',x='Name',y='Power',color='r',ax=axes[3,1])

good.sort_values('Combat').head(20).plot(kind='bar',x='Name',y='Combat',ax=axes[4,0])
bad.sort_values('Combat').head(20).plot(kind='bar',x='Name',y='Combat',color='r',ax=axes[4,1])

good.sort_values('Durability').head(20).plot(kind='bar',x='Name',y='Durability',ax=axes[5,0])
bad.sort_values('Durability').head(20).plot(kind='bar',x='Name',y='Durability',color='r',ax=axes[5,1])

good.sort_values('Total').head(20).plot(kind='bar',x='Name',y='Total',ax=axes[6,0])
bad.sort_values('Total').head(20).plot(kind='bar',x='Name',y='Total',color='r',ax=axes[6,1])

plt.show()

#most powerful heroes and villains in each stat category
#discrepencies in data for the Power category
