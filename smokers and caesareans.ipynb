# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

sns.set_style('whitegrid')
plt.rcParams['font.size']=12
plt.rcParams['figure.figsize']=(15,5)

df=pd.read_csv(r'C:\Users\TajwarAbtahee\OneDrive - JCW Resourcing\Desktop\Python\practice\LungCap.csv')
df.head()
# Out:
#    LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 0        6.475            6            62.1    no    male        no
# 1       10.125           18            74.7   yes  female        no
# 2        9.550           16            69.7    no  female       yes
# 3       11.125           14            71.0    no    male        no
# 4        4.800            5            56.9    no    male        no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725 entries, 0 to 724
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LungCap(cc)     725 non-null    float64
#  1   Age( years)     725 non-null    int64
#  2   Height(inches)  725 non-null    float64
#  3   Smoke           725 non-null    object
#  4   Gender          725 non-null    object
#  5   Caesarean       725 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 34.1+ KB

# %%
import numpy as np
df['smoke_val']=np.where(df.Smoke=='yes',1,0)
df['ces_val']=np.where(df.Caesarean=='yes',1,0)
df['Gender_val']=np.where(df.Gender=='male',1,0)

df.head()
# Out:
#    LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean  \
# 0        6.475            6            62.1    no    male        no
# 1       10.125           18            74.7   yes  female        no
# 2        9.550           16            69.7    no  female       yes
# 3       11.125           14            71.0    no    male        no
# 4        4.800            5            56.9    no    male        no
#
#    smoke_val  ces_val  Gender_val
# 0          0        0           1
# 1          1        0           0
# 2          0        1           0
# 3          0        0           1
# 4          0        0           1

# %%
df.describe()
# Out:
#        LungCap(cc)  Age( years)  Height(inches)   smoke_val     ces_val  \
# count   725.000000   725.000000      725.000000  725.000000  725.000000
# mean      7.863148    12.326897       64.836276    0.106207    0.226207
# std       2.662008     4.004750        7.202144    0.308315    0.418663
# min       0.507000     3.000000       45.300000    0.000000    0.000000
# 25%       6.150000     9.000000       59.900000    0.000000    0.000000
# 50%       8.000000    13.000000       65.400000    0.000000    0.000000
# 75%       9.800000    15.000000       70.300000    0.000000    0.000000
# max      14.675000    19.000000       81.800000    1.000000    1.000000
#
#        Gender_val
# count  725.000000
# mean     0.506207
# std      0.500307
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
sns.countplot(df.Gender)
print(df.Gender.value_counts())
# Out:
# male      367
# female    358
# Name: Gender, dtype: int64
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.Smoke)
print(df.Smoke.value_counts())
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# no     648
# yes     77
# Name: Smoke, dtype: int64

# %%
sns.countplot(df.Caesarean)
print(df.Caesarean.value_counts())
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# no     561
# yes    164
# Name: Caesarean, dtype: int64

# %%
df.corr().style.background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
# #T_4c3be_row0_col0,#T_4c3be_row1_col1,#T_4c3be_row2_col2,#T_4c3be_row3_col3,#T_4c3be_row4_col4,#T_4c3be_row5_col5{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_4c3be_row0_col1,#T_4c3be_row1_col2{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_4c3be_row0_col2{
#             background-color:  #17934e;
#             color:  #000000;
#         }#T_4c3be_row0_col3{
#             background-color:  #e44c34;
#             color:  #000000;
#         }#T_4c3be_row0_col4{
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }#T_4c3be_row0_col5{
#             background-color:  #f57547;
#             color:  #000000;
#         }#T_4c3be_row1_col0{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_4c3be_row1_col3{
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_4c3be_row1_col4{
# ...

# %%
sns.pairplot(df,vars=['LungCap(cc)','Age( years)','Height(inches)'],hue='Gender',kind='reg',size=5)
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df,vars=['LungCap(cc)','Age( years)','Height(inches)'],hue='Smoke',kind='reg',size=5)
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df,vars=['LungCap(cc)','Age( years)','Height(inches)'],hue='Caesarean',kind='reg',size=5)
# Out:
# C:\Users\TajwarAbtahee\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.groupby('Gender').sum().smoke_val.plot(kind='bar')
print(df.groupby('Gender').sum().smoke_val)
#most smokers were female
# Out:
# Gender
# female    44
# male      33
# Name: smoke_val, dtype: int32

# %%
df.groupby('Caesarean').sum().smoke_val.plot(kind='bar')
print(df.groupby('Caesarean').sum().smoke_val)
print(round((2100/77),ndigits=2),'%' + ' of women that had caesareans were smokers')
#most smokers were female
# Out:
# Caesarean
# no     56
# yes    21
# Name: smoke_val, dtype: int32
# 27.27 % of women that had caesareans were smokers

# %%
df.groupby('Caesarean').sum().Gender_val.plot(kind='bar')
print(df.groupby('Caesarean').sum().Gender_val)
print(round(8500/(282+85),ndigits=2),'%' + ' of men claimed to have caesareans')
# Out:
# Caesarean
# no     282
# yes     85
# Name: Gender_val, dtype: int32
# 23.16 % of men claimed to have caesareans

# %%
df[(df.Caesarean=='yes') & (df.Gender=='male')]
# Out:
#      LungCap(cc)  Age( years)  Height(inches) Smoke Gender Caesarean  \
# 6          4.950            8            63.3    no   male       yes
# 10        11.500           19            76.4    no   male       yes
# 15         9.525           13            63.5    no   male       yes
# 23         8.725           11            68.0    no   male       yes
# 25         8.350           12            61.3    no   male       yes
# ..           ...          ...             ...   ...    ...       ...
# 695        8.250           14            67.5    no   male       yes
# 712        3.425            3            51.0    no   male       yes
# 716        7.075           11            66.7    no   male       yes
# 718        7.175           17            68.8    no   male       yes
# 721        9.050           18            72.0   yes   male       yes
#
#      smoke_val  ces_val  Gender_val
# 6            0        1           1
# 10           0        1           1
# ...
